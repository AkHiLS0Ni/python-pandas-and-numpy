# %%
import pandas as pd

# %% [markdown]
# #Series

# %%
a = 200
b=500
c=400
data = [a,b,c]

series = pd.Series(data)
print(series)
# Out:
# 0    200
# 1    500
# 2    400
# dtype: int64

# %%
data = ['a','b','c']

series = pd.Series(data)
print(series)
# Out:
# 0    a
# 1    b
# 2    c
# dtype: object

# %%
data = [True,False]

series = pd.Series(data)
print(series)
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
a = 200
b=500
c=400
data = [a,b,c]

series = pd.Series(data, index=['a','b','c'])
print(series)
# Out:
# a    200
# b    500
# c    400
# dtype: int64

# %%
a = 200
b=500
c=400
data = [a,b,c]

series = pd.Series(data, index=['flore','flore','flore'])
print(series)
# Out:
# flore    200
# flore    500
# flore    400
# dtype: int64

# %%
a = 200
b=500
c=400
data = [a,b,c]

series = pd.Series(data, index=['a','b','c'])
print(series.loc["a"])



a = 200
b=500
c=400
data = [a,b,c]

series = pd.Series(data, index=['a','b','c'])
print(series.loc["b"])
# Out:
# 200
# 500

# %%
a = 200
b=500
c=400
data = [a,b,c]

series = pd.Series(data, index=['a','b','c'])
series.loc["c"] =200
print(series)
# Out:
# a    200
# b    500
# c    200
# dtype: int64

# %%
import pandas as pd

series = pd.Series([200, 500, 400, 700, 450], index=['a', 'b', 'c','d','e'])

print(series[series >=300])
# Out:
# b    500
# c    400
# d    700
# e    450
# dtype: int64

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)

print(myvar)
print(myvar["day1"])
print(myvar["day2"])
print(myvar["day3"])
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64
# 420
# 380
# 390

# %%
myvar.loc["day3"] += 3200

# %%
print(myvar["day3"])
# Out:
# 3590

# %%
calories = {"day1": 420, "day2": 380, "day3": 390}

myvar = pd.Series(calories)
print(myvar[myvar>=300])
# Out:
# day1    420
# day2    380
# day3    390
# dtype: int64

# %% [markdown]
# #DataFrame

# %%
data = {
    "Name" : ["harshit","babu","chotu"],
    "Age" : [30,39,24],
    "Salary":[10000,20000,30000]
}

df = pd.DataFrame(data)
print(df)

df = pd.DataFrame(data, index= ["EP1","EP2","EP3"])
print(df.loc["EP2"])
# Out:
#       Name  Age  Salary
# 0  harshit   30   10000
# 1     babu   39   20000
# 2    chotu   24   30000
# Name       babu
# Age          39
# Salary    20000
# Name: EP2, dtype: object

# %%
print(df.iloc[1])
# Out:
# Name       babu
# Age          39
# Salary    20000
# Name: EP2, dtype: object

# %%
print(df)
# Out:
#         Name  Age  Salary
# EP1  harshit   30   10000
# EP2     babu   39   20000
# EP3    chotu   24   30000

# %% [markdown]
# add a new colum

# %%
df["job"]= ["cook","waterboy", "n/a"]

# %% [markdown]
# add new column

# %%
new_row = pd.DataFrame([{"Name":"Sandy","Age":28,"job":"Engineer"},
                        {"Name":"alex","Age":28,"job":"Docter"}],
                       index=["EP4","EP5"])
df = pd.concat([df, new_row])

# %%
print(df)
# Out:
#         Name  Age   Salary       job
# EP1  harshit   30  10000.0      cook
# EP2     babu   39  20000.0  waterboy
# EP3    chotu   24  30000.0       n/a
# 0      Sandy   28      NaN  Engineer
# EP4    Sandy   28      NaN  Engineer
# EP4    Sandy   28      NaN  Engineer
# EP4    Sandy   28      NaN  Engineer
# EP4    Sandy   28      NaN  Engineer
# EP5     alex   28      NaN    Docter
# EP4    Sandy   28      NaN  Engineer
# EP5     alex   28      NaN    Docter

# %% [markdown]
# #Importing CSV & JSON

# %% [markdown]
# ai_student_impact_dataset (1)

# %%
df_csv = pd.read_csv('ai_student_impact_dataset (1).csv')
display(df_csv.head())
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
print(df_csv.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Student_ID                  50000 non-null  int64
#  1   Major_Category              50000 non-null  object
#  2   Year_of_Study               50000 non-null  object
#  3   Pre_Semester_GPA            50000 non-null  float64
#  4   Weekly_GenAI_Hours          50000 non-null  float64
#  5   Primary_Use_Case            50000 non-null  object
#  6   Prompt_Engineering_Skill    50000 non-null  object
#  7   Tool_Diversity              50000 non-null  int64
#  8   Paid_Subscription           50000 non-null  bool
#  9   Traditional_Study_Hours     50000 non-null  float64
#  10  Perceived_AI_Dependency     50000 non-null  int64
#  11  Institutional_Policy        50000 non-null  object
#  12  Anxiety_Level_During_Exams  50000 non-null  int64
# ...

# %%
print(df_csv.to_string())
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# #Selection

# %%
print(df_csv['Student_ID'])
# Out:
# 0        100001
# 1        100002
# 2        100003
# 3        100004
# 4        100005
#           ...
# 49995    149996
# 49996    149997
# 49997    149998
# 49998    149999
# 49999    150000
# Name: Student_ID, Length: 50000, dtype: int64

# %%
import pandas as pd

df = pd.read_csv("ai_student_impact_dataset (1).csv")

# %%
df["Major_Category"]
# Out:
# 0        Humanities
# 1           Medical
# 2          Business
# 3          Business
# 4              STEM
#             ...
# 49995      Business
# 49996          STEM
# 49997      Business
# 49998      Business
# 49999          Arts
# Name: Major_Category, Length: 50000, dtype: object

# %%
df[["Student_ID", "Major_Category", "Post_Semester_GPA"]]
# Out:
#        Student_ID Major_Category  Post_Semester_GPA
# 0          100001     Humanities              2.393
# 1          100002        Medical              3.696
# 2          100003       Business              3.499
# 3          100004       Business              4.000
# 4          100005           STEM              3.798
# ...           ...            ...                ...
# 49995      149996       Business              3.584
# 49996      149997           STEM              3.096
# 49997      149998       Business              3.605
# 49998      149999       Business              3.527
# 49999      150000           Arts              3.261
#
# [50000 rows x 3 columns]

# %%
df.head()
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
df.tail()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 49995               12.16       Copywriting/Drafting                 Beginner
# 49996                2.51       Copywriting/Drafting             Intermediate
# 49997               15.87        Summarizing_Reading                 Advanced
# 49998               19.91  Debugging/Troubleshooting             Intermediate
# 49999                3.30       Copywriting/Drafting                 Beginner
#
#        Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# ...

# %%
df.iloc[0:5]
# Out:
#    Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0      100001     Humanities        Senior             2.418
# 1      100002        Medical        Junior             3.821
# 2      100003       Business      Freshman             3.398
# 3      100004       Business        Senior             3.789
# 4      100005           STEM     Sophomore             3.635
#
#    Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0               23.31       Copywriting/Drafting                 Beginner
# 1                1.12                   Ideation                 Advanced
# 2               21.26        Summarizing_Reading                 Beginner
# 3                1.82       Copywriting/Drafting             Intermediate
# 4                9.29  Debugging/Troubleshooting                 Advanced
#
#    Tool_Diversity  Paid_Subscription  Traditional_Study_Hours  \
# 0               1               True                     8.13
# ...

# %%
df.iloc[5:10, 0:3]
# Out:
#    Student_ID Major_Category Year_of_Study
# 5      100006           STEM        Junior
# 6      100007           STEM      Freshman
# 7      100008           Arts        Junior
# 8      100009       Business     Sophomore
# 9      100010       Business     Sophomore

# %%
df.loc[0]
# Out:
# Student_ID                                   100001
# Major_Category                           Humanities
# Year_of_Study                                Senior
# Pre_Semester_GPA                              2.418
# Weekly_GenAI_Hours                            23.31
# Primary_Use_Case               Copywriting/Drafting
# Prompt_Engineering_Skill                   Beginner
# Tool_Diversity                                    1
# Paid_Subscription                              True
# Traditional_Study_Hours                        8.13
# Perceived_AI_Dependency                           5
# Institutional_Policy          Allowed_With_Citation
# Anxiety_Level_During_Exams                        6
# Post_Semester_GPA                             2.393
# Skill_Retention_Score                         86.44
# Burnout_Risk_Level                             High
# Name: 0, dtype: object

# %%
df.loc[0:5, ["Major_Category", "Post_Semester_GPA"]]
# Out:
#   Major_Category  Post_Semester_GPA
# 0     Humanities              2.393
# 1        Medical              3.696
# 2       Business              3.499
# 3       Business              4.000
# 4           STEM              3.798
# 5           STEM              3.666

# %% [markdown]
# 2. Filtering
# Students with GPA greater than 3

# %%
df[df["Post_Semester_GPA"] > 3]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# 5          100006           STEM        Junior             3.449
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 1                    1.12                   Ideation                 Advanced
# ...

# %%
df[df["Major_Category"] == "STEM"]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 4          100005           STEM     Sophomore             3.635
# 5          100006           STEM        Junior             3.449
# 6          100007           STEM      Freshman             3.622
# 10         100011           STEM      Graduate             3.407
# 13         100014           STEM        Junior             3.225
# ...           ...            ...           ...               ...
# 49980      149981           STEM      Graduate             3.419
# 49981      149982           STEM      Graduate             2.256
# 49988      149989           STEM     Sophomore             2.058
# 49993      149994           STEM     Sophomore             3.588
# 49996      149997           STEM        Senior             2.870
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 4                    9.29  Debugging/Troubleshooting                 Advanced
# ...

# %%
df[df["Paid_Subscription"] == "Yes"]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Major_Category, Year_of_Study, Pre_Semester_GPA, Weekly_GenAI_Hours, Primary_Use_Case, Prompt_Engineering_Skill, Tool_Diversity, Paid_Subscription, Traditional_Study_Hours, Perceived_AI_Dependency, Institutional_Policy, Anxiety_Level_During_Exams, Post_Semester_GPA, Skill_Retention_Score, Burnout_Risk_Level]
# Index: []

# %%
df[(df["Major_Category"] == "STEM") &
   (df["Post_Semester_GPA"] > 3)]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 4          100005           STEM     Sophomore             3.635
# 5          100006           STEM        Junior             3.449
# 6          100007           STEM      Freshman             3.622
# 10         100011           STEM      Graduate             3.407
# 13         100014           STEM        Junior             3.225
# ...           ...            ...           ...               ...
# 49973      149974           STEM      Graduate             3.317
# 49974      149975           STEM        Junior             3.087
# 49980      149981           STEM      Graduate             3.419
# 49993      149994           STEM     Sophomore             3.588
# 49996      149997           STEM        Senior             2.870
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 4                    9.29  Debugging/Troubleshooting                 Advanced
# ...

# %%
df[df["Major_Category"].isin(["Business", "Medical"])]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 8          100009       Business     Sophomore             3.420
# 9          100010       Business     Sophomore             3.046
# ...           ...            ...           ...               ...
# 49990      149991       Business        Senior             2.970
# 49992      149993       Business      Graduate             2.829
# 49995      149996       Business        Senior             2.899
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 1                    1.12                   Ideation                 Advanced
# ...

# %%
df[df["Paid_Subscription"] != "Yes"]
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %% [markdown]
# 3. Aggregation
# Mean GPA

# %%
df["Post_Semester_GPA"].mean()
# Out:
# np.float64(3.34929942)

# %%
df["Post_Semester_GPA"].max()
# Out:
# 4.0

# %%
df["Weekly_GenAI_Hours"].sum()
# Out:
# np.float64(421387.61)

# %%
df.groupby("Major_Category")["Post_Semester_GPA"].mean()
# Out:
# Major_Category
# Arts          3.343688
# Business      3.336085
# Humanities    3.345825
# Medical       3.353168
# STEM          3.363154
# Name: Post_Semester_GPA, dtype: float64

# %%
df.groupby("Major_Category")["Weekly_GenAI_Hours"].mean()
# Out:
# Major_Category
# Arts           7.271702
# Business       8.275898
# Humanities     6.770144
# Medical        7.546728
# STEM          10.488609
# Name: Weekly_GenAI_Hours, dtype: float64

# %%
df.groupby("Major_Category").agg({
    "Post_Semester_GPA":"mean",
    "Weekly_GenAI_Hours":"sum",
    "Skill_Retention_Score":"max"
})
# Out:
#                 Post_Semester_GPA  Weekly_GenAI_Hours  Skill_Retention_Score
# Major_Category
# Arts                     3.343688            43143.01                  100.0
# Business                 3.336085           103763.21                  100.0
# Humanities               3.345825            67660.82                  100.0
# Medical                  3.353168            48872.61                  100.0
# STEM                     3.363154           157947.96                  100.0

# %%
df.isnull()
# Out:
#        Student_ID  Major_Category  Year_of_Study  Pre_Semester_GPA  \
# 0           False           False          False             False
# 1           False           False          False             False
# 2           False           False          False             False
# 3           False           False          False             False
# 4           False           False          False             False
# ...           ...             ...            ...               ...
# 49995       False           False          False             False
# 49996       False           False          False             False
# 49997       False           False          False             False
# 49998       False           False          False             False
# 49999       False           False          False             False
#
#        Weekly_GenAI_Hours  Primary_Use_Case  Prompt_Engineering_Skill  \
# 0                   False             False                     False
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                    0
# Major_Category                0
# Year_of_Study                 0
# Pre_Semester_GPA              0
# Weekly_GenAI_Hours            0
# Primary_Use_Case              0
# Prompt_Engineering_Skill      0
# Tool_Diversity                0
# Paid_Subscription             0
# Traditional_Study_Hours       0
# Perceived_AI_Dependency       0
# Institutional_Policy          0
# Anxiety_Level_During_Exams    0
# Post_Semester_GPA             0
# Skill_Retention_Score         0
# Burnout_Risk_Level            0
# dtype: int64

# %%
df.dropna()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df.dropna()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df.fillna(0)
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df["Post_Semester_GPA"].fillna(df["Post_Semester_GPA"].mean())
# Out:
# 0        2.393
# 1        3.696
# 2        3.499
# 3        4.000
# 4        3.798
#          ...
# 49995    3.584
# 49996    3.096
# 49997    3.605
# 49998    3.527
# 49999    3.261
# Name: Post_Semester_GPA, Length: 50000, dtype: float64

# %%
df.drop_duplicates()
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.rename(columns={
    "Post_Semester_GPA":"Final_GPA"
})
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 0          100001     Humanities        Senior             2.418
# 1          100002        Medical        Junior             3.821
# 2          100003       Business      Freshman             3.398
# 3          100004       Business        Senior             3.789
# 4          100005           STEM     Sophomore             3.635
# ...           ...            ...           ...               ...
# 49995      149996       Business        Senior             2.899
# 49996      149997           STEM        Senior             2.870
# 49997      149998       Business        Senior             3.177
# 49998      149999       Business        Junior             3.398
# 49999      150000           Arts     Sophomore             3.242
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 0                   23.31       Copywriting/Drafting                 Beginner
# ...

# %%
year_mapping = {
    'Freshman': 1,
    'Sophomore': 2,
    'Junior': 3,
    'Senior': 4,
    'Graduate': 5
}
df["Year_of_Study"] = df["Year_of_Study"].replace(year_mapping).astype(int)
# Out:
# /tmp/ipykernel_20021/3293639108.py:8: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df["Year_of_Study"] = df["Year_of_Study"].replace(year_mapping).astype(int)

# %%
df["Paid_Subscription"] = df["Paid_Subscription"].replace({
    "Yes":"Subscribed",
    "No":"Not Subscribed"
})

# %%
df.sort_values("Post_Semester_GPA", ascending=False)
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 49979      149980       Business        Senior             3.750
# 49976      149977       Business      Graduate             3.692
# 29         100030           STEM     Sophomore             3.638
# 25         100026           Arts        Senior             3.308
# 49950      149951     Humanities      Freshman             3.848
# ...           ...            ...           ...               ...
# 11360      111361           Arts      Freshman             1.408
# 39393      139394        Medical        Junior             1.703
# 10884      110885       Business      Freshman             1.183
# 43351      143352     Humanities        Junior             1.346
# 18078      118079           STEM        Junior             1.431
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 49979               16.00                   Ideation                 Beginner
# ...

# %%
df.sort_values("Weekly_GenAI_Hours")
# Out:
#        Student_ID Major_Category Year_of_Study  Pre_Semester_GPA  \
# 23628      123629     Humanities        Junior             1.543
# 11590      111591     Humanities     Sophomore             3.529
# 39443      139444     Humanities        Junior             3.338
# 5360       105361       Business     Sophomore             3.008
# 34516      134517       Business        Junior             3.630
# ...           ...            ...           ...               ...
# 8502       108503           STEM     Sophomore             3.047
# 15933      115934           STEM        Junior             2.739
# 42300      142301       Business        Junior             2.698
# 49937      149938       Business      Freshman             3.113
# 36328      136329       Business     Sophomore             2.251
#
#        Weekly_GenAI_Hours           Primary_Use_Case Prompt_Engineering_Skill  \
# 23628                 0.0   Direct_Answer_Generation                 Beginner
# ...
